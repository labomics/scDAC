# %%
from os import path
from os.path import join as pj 
import time
import argparse 

from tqdm import tqdm 
import math
import numpy as np
import torch as th
import pandas as pd
import os
from torch import nn, autograd
import matplotlib.pyplot as plt
import umap

from modules import model1, utils
from modules.datasets import MultimodalDataset
from modules.datasets import MultiDatasetSampler
from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn import metrics
from sklearn.mixture import BayesianGaussianMixture
from sklearn.metrics import silhouette_score

# %%
parser = argparse.ArgumentParser()
## Task
parser.add_argument('--task', type=str, default='Zilionis',
    help="Choose a task")
parser.add_argument('--reference', type=str, default='',
    help="Choose a reference task")
parser.add_argument('--exp', type=str, default='e0',
    help="Choose an experiment")
parser.add_argument('--model', type=str, default='default',
    help="Choose a model configuration")
# parser.add_argument('--data', type=str, default='sup',
#     help="Choose a data configuration")
parser.add_argument('--action', type=str, default='train',
    help="Choose an action to run")
parser.add_argument('--method', type=str, default='scDAC',
    help="Choose an method to benchmark")
parser.add_argument('--init-model', type=str, default='',
    help="Load a saved model")
parser.add_argument('--mods-conditioned', type=str, nargs='+', default=[],
    help="Modalities conditioned for sampling")
parser.add_argument('--data-conditioned', type=str, default='prior.csv',
    help="Data conditioned for sampling")
parser.add_argument('--sample-num', type=int, default=0,
    help='Number of samples to be generated')
parser.add_argument('--input-mods', type=str, nargs='+', default=[],
    help="Input modalities for transformation")
## Training
parser.add_argument('--epoch-num', type=int, default=600,
    help='Number of epochs to train')
parser.add_argument('--lr', type=float, default=1e-4,
    help='Learning rate')
#parser.add_argument('--dim_logitx', type=int, default=64,
#    help='dim_logitx')
parser.add_argument('--grad-clip', type=float, default=-1,
    help='Gradient clipping value')
parser.add_argument('--s-drop-rate', type=float, default=0.1,
    help="Probility of dropping out subject ID during training")
parser.add_argument('--seed', type=int, default=-1,
    help="Set the random seed to reproduce the results")
parser.add_argument('--use-shm', type=int, default=1,
    help="Use shared memory to accelerate training")
## Debugging
parser.add_argument('--print-iters', type=int, default=-1,
    help="Iterations to print training messages")
parser.add_argument('--log-epochs', type=int, default=100,
    help='Epochs to log the training states')
parser.add_argument('--save-epochs', type=int, default=1,
    help='Epochs to save the latest training states (overwrite previous ones)')
parser.add_argument('--time', type=int, default=0, choices=[0, 1],
    help='Time the forward and backward passes')
parser.add_argument('--debug', type=int, default=1, choices=[0, 1],
    help='Print intermediate variables')
# o, _ = parser.parse_known_args()  # for python interactive
o = parser.parse_known_args()[0]

# %%
data_config = None
net = None
#discriminator = None 
optimizer_net = None
#optimizer_disc = None
benchmark = {
    "train_loss": [],
    "test_loss": [],
    "foscttm": [],
    "epoch_id_start": 0
}

# %%
def main():
    initialize()
    if o.action == "print_model":
        print_model() ##
    elif o.action == "train":
        train() #
    elif o.action == "test":
        test() ###
    elif o.action == "infer_latent":
        infer_latent(only_joint=False, impute=False, save_input=True)###

    else:
        assert False, "Invalid action!"

# %%
def initialize():
    init_seed() ##
    init_dirs() ##
    load_data_config() ##
    load_model_config() ##
    get_gpu_config() ##
    init_model() ##


def init_seed():
    if o.seed >= 0:
        np.random.seed(o.seed) 
        th.manual_seed(o.seed) 
        th.cuda.manual_seed_all(o.seed)


def init_dirs():
    if o.use_shm == 1:
        o.data_dir = pj("/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data", "processed",  o.task)
    else:
        o.data_dir = pj("/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data", "processed", o.task)
    o.result_dir = pj("result", o.task, o.exp, o.model)
    if o.reference == '': 
        o.train_dir = pj("result", o.task, o.exp, o.model, "train")
    else:
        o.train_dir = pj("result", o.reference, o.exp, o.model, "train")
    o.debug_dir = pj(o.result_dir, "debug")
    utils.mkdirs([o.train_dir, o.debug_dir])
    print("Task: %s\nExperiment: %s\nModel: %s\n" % (o.task, o.exp, o.model))


def load_data_config():
    get_dims_x()
    o.mods = list(o.dims_x.keys())
    o.mod_num = len(o.dims_x)
    global data_config
    data_config = utils.load_toml("configs/data.toml")[o.task]
    for k, v in data_config.items():
        vars(o)[k] = v

    o.s_joint, o.combs, o.s, o.dims_s = utils.gen_all_batch_ids(o.s_joint, o.combs)
    

    
    if o.reference != '':
        data_config_ref = utils.load_toml("configs/data.toml")[o.reference]
        _, _, _, o.dims_s = utils.gen_all_batch_ids(data_config_ref["s_joint"], 
                                                    data_config_ref["combs"])



def load_model_config():
    model_config = utils.load_toml("configs/model.toml")["default"]
    if o.model != "default":
        model_config.update(utils.load_toml("configs/model.toml")[o.model])
    for k, v in model_config.items():
        vars(o)[k] = v
    o.dim_z = o.dim_c
    o.dims_dec_x = o.dims_enc_x[::-1]
    if "dims_enc_chr" in vars(o).keys():
        o.dims_dec_chr = o.dims_enc_chr[::-1]
    o.dims_h = {}
    for m, dim in o.dims_x.items():
        o.dims_h[m] = dim if m != "atac" else o.dims_enc_chr[-1] * 22
    print("dims_h:", o.dims_h)

def get_gpu_config():
    o.G = 1  # th.cuda.device_count()  # get GPU number
    o.N = 512
    assert o.N % o.G == 0, "Please ensure the mini-batch size can be divided " \
        "by the GPU number"
    o.n = o.N // o.G
    print("Total mini-batch size: %d, GPU number: %d, GPU mini-batch size: %d" % (o.N, o.G, o.n))


def init_model():
    """
    Initialize the model, optimizer, and benchmark
    """
    global net, optimizer_net
    net = model1.Net_DP(o).cuda()
    optimizer_net = th.optim.AdamW(net.parameters(), lr=o.lr)
    if o.init_model != '':
        fpath = pj(o.train_dir, o.init_model)
        savepoint = th.load(fpath+".pt")
        net.load_state_dict(savepoint['net_states'])
        optimizer_net.load_state_dict(savepoint['optim_net_states'])
        benchmark.update(utils.load_toml(fpath+".toml")['benchmark'])
        print('Model is initialized from ' + fpath + ".pt")
    net_param_num = sum([param.data.numel() for param in net.parameters()])
    print('Parameter number: %.3f M' % (net_param_num / 1e6))


def print_model():
    #global net, discriminator
    global net
    with open(pj(o.result_dir, "model_architecture.txt"), 'w') as f:
        print(net, file=f)


def get_dims_x():
    dims_x = utils.load_csv(pj(o.data_dir, "feat", "feat_dims.csv"))
    dims_x = utils.transpose_list(dims_x)
    o.dims_x = {}
    for i in range(1, len(dims_x)):
        m = dims_x[i][0]
        if m == "atac":
            o.dims_chr = list(map(int, dims_x[i][1:]))
            o.dims_x[m] = sum(o.dims_chr)
        else:
            o.dims_x[m] = int(dims_x[i][1])


    print("Input feature numbers: ", o.dims_x)


def train():
    train_data_loader_cat = get_dataloader_cat("train")
    epoch_id_list = []
    ari_list = []
    nmi_list = []
    sc_list = []

    for epoch_id in range(benchmark['epoch_id_start'], o.epoch_num):
        run_epoch(train_data_loader_cat, "train", epoch_id)
        if epoch_id >550:

            z = infer_latent_dp(save_input=False)
            net.loss_calculator_dp.mean_dp, net.loss_calculator_dp.weight_concentration_dp,net.loss_calculator_dp.mean_precision_dp,net.loss_calculator_dp.precisions_cholesky_dp, net.loss_calculator_dp.degrees_of_freedom_dp, net.scdp.predict_label = dp(z)

            epoch_id_list.append(epoch_id)

        else:
            pass            
        check_to_save(epoch_id)

# %%
if o.task == 'chen_10':
    path_label = './data/label_chen_10.csv'
elif o.task == 'baron_single':
    path_label = '/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data/b1/label_seurat/l1.csv'    
elif o.task == 'Kozareva_total':
    path_label = '/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data/k_t/label_seurat/label1.csv'    
elif o.task == 'Orozco':
    path_label = '/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data/o1/label_seurat/label.csv' 
elif o.task == 'Slyper':
    path_label = '/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data/s1/label_seurat/label_new.csv' 
elif o.task == 'Zilionis':
    path_label = '/root/data/asj/2023/0118/sc-transformer-gmvaextoytoz/data/z1/label_seurat/label.csv' 
else:
    path_label = './data/label_chen_8.csv'

# %%
def dp(z):
    # z_np = (z).cpu().detach().numpy()   
    z_np = z.cpu().detach().numpy()   
    bgm = BayesianGaussianMixture(
        n_components=50, weight_concentration_prior=1e-10,mean_precision_prior = 80,covariance_type='diag',init_params ='kmeans', max_iter=1000
        ).fit(z_np)
    predict_label_array = bgm.predict(z_np)
    predict_label_array = bgm.predict(z_np)
    predict_label = th.Tensor(np.array(predict_label_array)).unsqueeze(1).cuda()
    mean_dp = th.Tensor(np.array(bgm.means_))
    weight_concentration_dp = th.Tensor(np.array(bgm.weight_concentration_))
    precisions_cholesky_dp = th.Tensor(np.array(bgm.precisions_cholesky_))
    degrees_of_freedom_dp = th.Tensor(np.array(bgm.degrees_of_freedom_))
    mean_precision_dp = th.Tensor(np.array(bgm.mean_precision_))   
    return mean_dp, weight_concentration_dp, mean_precision_dp, precisions_cholesky_dp, degrees_of_freedom_dp, predict_label

def dp_infer(z):
    # z_np = (z).cpu().detach().numpy()   
    z_np = z.cpu().detach().numpy()   
    bgm = BayesianGaussianMixture(
        n_components=50, weight_concentration_prior=1e-10,mean_precision_prior = 80, covariance_type='diag',  init_params ='kmeans', max_iter=1000
        ).fit(z_np)
    predict_label_array = bgm.predict(z_np)
    predict_label = th.Tensor(np.array(predict_label_array)).unsqueeze(1).cuda()
    mean_dp = th.Tensor(np.array(bgm.means_))
    weight_concentration_dp = th.Tensor(np.array(bgm.weight_concentration_))
    precisions_cholesky_dp = th.Tensor(np.array(bgm.precisions_cholesky_))
    degrees_of_freedom_dp = th.Tensor(np.array(bgm.degrees_of_freedom_))
    mean_precision_dp = th.Tensor(np.array(bgm.mean_precision_))   
    return mean_dp, weight_concentration_dp, mean_precision_dp, precisions_cholesky_dp, degrees_of_freedom_dp, predict_label

# %%
def get_dataloaders(split, train_ratio=None):
    data_loaders = {}
    for subset in range(len(o.s)):
        data_loaders[subset] = get_dataloader(subset, split, train_ratio=train_ratio)
    return data_loaders


def get_dataloader(subset, split, train_ratio=None):
    dataset = MultimodalDataset(o.task, o.data_dir, subset, split, train_ratio=train_ratio)
    shuffle = True if split == "train" else False
    # shuffle = False
    data_loader = th.utils.data.DataLoader(dataset, batch_size=o.N, shuffle=shuffle,
                                           num_workers=64, pin_memory=True)
    print("Subset: %d, modalities %s: %s size: %d" %
          (subset, str(o.combs[subset]), split, dataset.size))
    return data_loader


def get_dataloader_cat(split, train_ratio=None):
    datasets = []
    for subset in range(len(o.s)):
        datasets.append(MultimodalDataset(o.task, o.data_dir, subset, split, train_ratio=train_ratio))
        print("Subset: %d, modalities %s: %s size: %d" %  (subset, str(o.combs[subset]), split,
            datasets[subset].size))
    dataset_cat = th.utils.data.dataset.ConcatDataset(datasets)
    shuffle = True if split == "train" else False
    # shuffle = False
    sampler = MultiDatasetSampler(dataset_cat, batch_size=o.N, shuffle=shuffle)
    data_loader = th.utils.data.DataLoader(dataset_cat, batch_size=o.N, sampler=sampler, 
        num_workers=64, pin_memory=True)
    return data_loader

# %%
def get_eval_dataloader(train_ratio=False):
    data_config_new = utils.copy_dict(data_config)
    data_config_new.update({"combs": [o.mods], "comb_ratios": [1]})
    if train_ratio:
        data_config_new.update({"train_ratio": train_ratio})
    dataset = MultimodalDataset(data_config_new, o.mods, "test")
    data_loader = th.utils.data.DataLoader(dataset, batch_size=o.N,
        shuffle=False, num_workers=64, pin_memory=True)
    print("Eval Dataset %s: test: %d\n" % (str(o.mods), dataset.size))
    return data_loader


def test():
    data_loaders = get_dataloaders()
    run_epoch(data_loaders, "test")

# %%
def run_epoch(data_loader, split, epoch_id=0):
    if split == "train":
        net.train()
    elif split == "test":
        net.eval()
    else:
        assert False, "Invalid split: %s" % split
    net.o.epoch_id = epoch_id
    loss_total = 0
    for i, data in enumerate(data_loader):
        loss = run_iter(split, data)
        loss_total += loss
        if o.print_iters > 0 and (i+1) % o.print_iters == 0:
            print('Epoch: %d/%d, Batch: %d/%d, %s loss: %.3f' % (epoch_id+1,
            o.epoch_num, i+1, len(data_loader), split, loss))
    loss_avg = loss_total / len(data_loader)
    print('Epoch: %d/%d, %s loss: %.3f\n' % (epoch_id+1, o.epoch_num, split, loss_avg))
    benchmark[split+'_loss'].append((float(epoch_id), float(loss_avg)))
    return loss_avg



def run_iter(split, inputs):
    inputs = utils.convert_tensors_to_cuda(inputs)
    if split == "train":
        with autograd.set_detect_anomaly(o.debug == 1):
            loss_net = forward_net(inputs)
            loss = loss_net
            update_net(loss) 
            
            
            
    else:
        with th.no_grad():
            loss_net = forward_net(inputs)
            loss = loss_net
    
    return loss.item()


def forward_net(inputs):
    return net(inputs)


def update_net(loss):
    update(loss, net, optimizer_net)

    

def update(loss, model, optimizer):
    optimizer.zero_grad()
    loss.backward()

    if o.grad_clip > 0:
        nn.utils.clip_grad_norm_(model.parameters(), o.grad_clip)
    optimizer.step()


def check_to_save(epoch_id):
    if (epoch_id+1) % o.log_epochs == 0 or epoch_id+1 == o.epoch_num:
        save_training_states(epoch_id, "sp_%08d" % epoch_id)
    if (epoch_id+1) % o.save_epochs == 0 or epoch_id+1 == o.epoch_num:
        save_training_states(epoch_id, "sp_latest")


def save_training_states(epoch_id, filename):
    benchmark['epoch_id_start'] = epoch_id
    utils.save_toml({"o": vars(o), "benchmark": benchmark}, pj(o.train_dir, filename+".toml"))
    th.save({"net_states": net.state_dict(),
             "optim_net_states": optimizer_net.state_dict(),
            }, pj(o.train_dir, filename+".pt"))




def infer_latent_dp(save_input=False):
    print("Inferring ...")
    dirs = {}
    base_dir = pj(o.result_dir, "represent", o.init_model)
    data_loaders = get_dataloaders("test", train_ratio=0)
    net.eval()
    with th.no_grad():
        for subset_id, data_loader in data_loaders.items():
            print("Processing subset %d: %s" % (subset_id, str(o.combs[subset_id])))
            dirs[subset_id] = {"z": {}, "x_r_pre": {}, "x": {}}
            dirs[subset_id]["z"]["rna"] = pj(base_dir, "subset_"+str(subset_id), "z", "rna")
            utils.mkdirs(dirs[subset_id]["z"]["rna"], remove_old=False)          
            z_list = []
            if save_input:
                for m in o.combs[subset_id]:
                    dirs[subset_id]["x"][m] = pj(base_dir, "subset_"+str(subset_id), "x", m)
                    utils.mkdirs(dirs[subset_id]["x"][m], remove_old=True)
            fname_fmt = utils.get_name_fmt(len(data_loader))+".csv"    
            for i, data in enumerate(data_loader):
                data = utils.convert_tensors_to_cuda(data)
                _, z= net.scdp(data)      
                z_list.append(z)
                z_all = th.cat(z_list, dim = 0)
    return(z_all)

# %%
def infer_latent(only_joint=True, impute=False, save_input=False):
    print("Inferring ...")
    dirs = {}
    base_dir = pj(o.result_dir, "represent", o.init_model)
    data_loaders = get_dataloaders("test", train_ratio=0)
    net.eval()
    with th.no_grad():
        # z_all_large = []
        for subset_id, data_loader in data_loaders.items():
            print("Processing subset %d: %s" % (subset_id, str(o.combs[subset_id])))
            
            #dirs[subset_id] = {"z": {}, "x_r": {}, "x": {}, "w_lis1": {}}
            # dirs[subset_id] = {"z": {}, "x_r_pre": {}, "x": {}, "y_cat_list": {}, "c_ymu": {}, "n_covariance2": {}, "n_mu": {}, "d2": {}, "w_covariance3": {}}
            # dirs[subset_id] = {"z": {}, "x_r_pre": {}, "x": {}, "predict_label":{}}
            dirs[subset_id] = {"z": {}, "x_r_pre": {}, "x": {}}
            dirs[subset_id]["z"]["joint"] = pj(base_dir, "subset_"+str(subset_id), "z", "joint")
            utils.mkdirs(dirs[subset_id]["z"]["joint"], remove_old=True)
            if not only_joint:
                for m in o.combs[subset_id]:
                    dirs[subset_id]["z"][m] = pj(base_dir, "subset_"+str(subset_id), "z", m)
                    utils.mkdirs(dirs[subset_id]["z"][m], remove_old=True)

                    dirs[subset_id]["x_r_pre"][m] = pj(base_dir, "subset_"+str(subset_id), "x_r_pre", m)
                    utils.mkdirs(dirs[subset_id]["x_r_pre"][m], remove_old=True)
       
            if impute:
                for m in o.mods:
                    dirs[subset_id]["x_r"][m] = pj(base_dir, "subset_"+str(subset_id), "x_r", m)
                    utils.mkdirs(dirs[subset_id]["x_r"][m], remove_old=True)
            if save_input:
                for m in o.combs[subset_id]:
                    dirs[subset_id]["x"][m] = pj(base_dir, "subset_"+str(subset_id), "x", m)
                    utils.mkdirs(dirs[subset_id]["x"][m], remove_old=True)
            fname_fmt = utils.get_name_fmt(len(data_loader))+".csv"
            
            for i, data in enumerate(tqdm(data_loader)):
                data = utils.convert_tensors_to_cuda(data)
                # conditioned on all observed modalities
                #x_r_pre, _, _, _, z, _, _, *_ = net.dpmm(data)  # N * K
                x_r_pre, z= net.scdp(data) 
                utils.save_tensor_to_csv(z, pj(dirs[subset_id]["z"]["joint"], fname_fmt) % i)
                # utils.save_tensor_to_csv(x_r_pre[m], pj(dirs[subset_id]["x_r_pre"][m], fname_fmt) % i)
                # utils.save_tensor_to_csv(predict_label, pj(dirs[subset_id]["predict_label"], fname_fmt) % i)
                if impute:
                    x_r = model1.gen_real_data(x_r_pre, sampling=True)
                    for m in o.mods:
                        utils.save_tensor_to_csv(x_r[m], pj(dirs[subset_id]["x_r"][m], fname_fmt) % i)
                if save_input:
                    for m in o.combs[subset_id]:
                        utils.save_tensor_to_csv(data["x"][m], pj(dirs[subset_id]["x"][m], fname_fmt) % i)

                # conditioned on each individual modalities
                if not only_joint:
                    for m in data["x"].keys():
                        input_data = {
                            "x": {m: data["x"][m]},
                            "s": data["s"],  
                            "e": {}
                        }
                        if m in data["e"].keys():
                            input_data["e"][m] = data["e"][m]
                        #_, _, _, _, z, c, b, *_ = net.sct(input_data)  # N * K
                        # _, c_ymu, _, _, _, z, y_cat_list, _, _, _, n_covariance2, n_mu, d2, w_covariance3, _ = net.dpmm(input_data)  # N * K
                        _, z= net.scdp(input_data)  # N * K
                    
                        # print(input_data['x']['rna'].shape, z.shape)
                        utils.save_tensor_to_csv(z, pj(dirs[subset_id]["z"][m], fname_fmt) % i)    
                        # utils.save_tensor_to_csv(predict_label, pj(dirs[subset_id]["predict_label"][m], fname_fmt) % i)  
                    if i >0:
                        z_all = th.cat((z_all, z), dim = 0)
                    else:
                        z_all = z
            # z_all_large.append(z_all)
        _, _, _, _, _, predict_label = dp_infer(z_all)
        if o.task == 'chen_10':
            utils.save_tensor_to_csv(z_all, './result/chen_10/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/chen_10/e0/default/represent/y.csv')   
        elif o.task == 'baron_single':
            utils.save_tensor_to_csv(z_all, './result/baron_single/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/baron_single/e0/default/represent/y.csv')    
        elif o.task == 'Kozareva_total':
            utils.save_tensor_to_csv(z_all, './result/Kozareva_total/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/Kozareva_total/e0/default/represent/y.csv')   
        elif o.task == 'Orozco':
            utils.save_tensor_to_csv(z_all, './result/Orozco/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/Orozco/e0/default/represent/y.csv')   
        elif o.task == 'Slyper':
            utils.save_tensor_to_csv(z_all, './result/Slyper/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/Slyper/e0/default/represent/y.csv')   
        elif o.task == 'Zilionis':
            utils.save_tensor_to_csv(z_all, './result/Zilionis/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/Zilionis/e0/default/represent/y.csv')   
        else:
            utils.save_tensor_to_csv(z_all, './result/chen_10/e0/default/represent/z.csv')
            utils.save_tensor_to_csv(predict_label, './result/chen_10/e0/default/represent/y.csv')   

        z_all_cpu = z_all.cpu()
        predict_label_cpu = predict_label.cpu()
        label_true = utils.load_csv(path_label)
        label_tlist = utils.transpose_list(label_true)[1][1:]
        label_plist = utils.transpose_list(predict_label_cpu)[0]
        ari = adjusted_rand_score(label_tlist, label_plist) #l1 kpca20
        nmi = normalized_mutual_info_score(label_tlist, label_plist)
        sc = silhouette_score(z_all_cpu, label_plist)
        print("ari:", ari)
        print("nmi:", nmi)
        print("sc:", (1+sc)/2)

# %%
initialize()
# if o.action == "print_model":
print_model() ##
# elif o.action == "train":
train() #
# Out:
# Task: Zilionis
# Experiment: e0
# Model: default
#
# Input feature numbers:  {'rna': 4000}
# dims_h: {'rna': 4000}
# Total mini-batch size: 512, GPU number: 1, GPU mini-batch size: 512
# Parameter number: 2.128 M
# Subset: 0, modalities ['rna']: train size: 34558
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 1/600, train loss: 4100.790
#
# Epoch: 2/600, train loss: 2497.048
#
# Epoch: 3/600, train loss: 1964.840
#
# Epoch: 4/600, train loss: 1747.822
#
# Epoch: 5/600, train loss: 1609.764
#
# Epoch: 6/600, train loss: 1530.381
#
# Epoch: 7/600, train loss: 1481.011
#
# Epoch: 8/600, train loss: 1438.650
#
# Epoch: 9/600, train loss: 1400.213
#
# Epoch: 10/600, train loss: 1369.893
#
# Epoch: 11/600, train loss: 1347.862
#
# Epoch: 12/600, train loss: 1330.451
#
# Epoch: 13/600, train loss: 1315.011
#
# Epoch: 14/600, train loss: 1301.752
#
# Epoch: 15/600, train loss: 1289.662
#
# Epoch: 16/600, train loss: 1279.619
#
# Epoch: 17/600, train loss: 1270.892
#
# Epoch: 18/600, train loss: 1262.857
#
# Epoch: 19/600, train loss: 1256.135
#
# Epoch: 20/600, train loss: 1249.656
#
# Epoch: 21/600, train loss: 1243.969
#
# Epoch: 22/600, train loss: 1238.698
#
# Epoch: 23/600, train loss: 1232.998
#
# Epoch: 24/600, train loss: 1228.885
#
# Epoch: 25/600, train loss: 1224.518
#
# Epoch: 26/600, train loss: 1220.538
#
# Epoch: 27/600, train loss: 1216.416
#
# Epoch: 28/600, train loss: 1213.068
#
# Epoch: 29/600, train loss: 1209.267
#
# Epoch: 30/600, train loss: 1206.269
#
# Epoch: 31/600, train loss: 1202.917
#
# Epoch: 32/600, train loss: 1199.766
#
# Epoch: 33/600, train loss: 1196.934
#
# Epoch: 34/600, train loss: 1194.451
#
# Epoch: 35/600, train loss: 1191.906
#
# Epoch: 36/600, train loss: 1189.612
#
# Epoch: 37/600, train loss: 1186.919
#
# Epoch: 38/600, train loss: 1184.739
#
# Epoch: 39/600, train loss: 1182.499
#
# Epoch: 40/600, train loss: 1180.809
#
# Epoch: 41/600, train loss: 1178.741
#
# Epoch: 42/600, train loss: 1177.113
#
# Epoch: 43/600, train loss: 1175.098
#
# Epoch: 44/600, train loss: 1173.105
#
# Epoch: 45/600, train loss: 1171.243
#
# Epoch: 46/600, train loss: 1169.800
#
# Epoch: 47/600, train loss: 1168.330
#
# Epoch: 48/600, train loss: 1166.752
#
# Epoch: 49/600, train loss: 1165.244
#
# Epoch: 50/600, train loss: 1163.936
#
# Epoch: 51/600, train loss: 1162.172
#
# Epoch: 52/600, train loss: 1161.060
#
# Epoch: 53/600, train loss: 1159.597
#
# Epoch: 54/600, train loss: 1158.262
#
# Epoch: 55/600, train loss: 1157.031
#
# Epoch: 56/600, train loss: 1155.945
#
# Epoch: 57/600, train loss: 1154.780
#
# Epoch: 58/600, train loss: 1153.720
#
# Epoch: 59/600, train loss: 1152.434
#
# Epoch: 60/600, train loss: 1151.472
#
# Epoch: 61/600, train loss: 1150.315
#
# Epoch: 62/600, train loss: 1149.407
#
# Epoch: 63/600, train loss: 1148.337
#
# Epoch: 64/600, train loss: 1147.262
#
# Epoch: 65/600, train loss: 1146.231
#
# Epoch: 66/600, train loss: 1144.895
#
# Epoch: 67/600, train loss: 1143.954
#
# Epoch: 68/600, train loss: 1142.822
#
# Epoch: 69/600, train loss: 1142.330
#
# Epoch: 70/600, train loss: 1141.330
#
# Epoch: 71/600, train loss: 1140.081
#
# Epoch: 72/600, train loss: 1139.163
#
# Epoch: 73/600, train loss: 1138.241
#
# Epoch: 74/600, train loss: 1137.512
#
# Epoch: 75/600, train loss: 1136.702
#
# Epoch: 76/600, train loss: 1136.086
#
# Epoch: 77/600, train loss: 1135.019
#
# Epoch: 78/600, train loss: 1134.063
#
# Epoch: 79/600, train loss: 1133.425
#
# Epoch: 80/600, train loss: 1132.861
#
# Epoch: 81/600, train loss: 1132.023
#
# Epoch: 82/600, train loss: 1131.088
#
# Epoch: 83/600, train loss: 1130.187
#
# Epoch: 84/600, train loss: 1129.486
#
# Epoch: 85/600, train loss: 1128.925
#
# Epoch: 86/600, train loss: 1127.996
#
# Epoch: 87/600, train loss: 1127.400
#
# Epoch: 88/600, train loss: 1126.706
#
# Epoch: 89/600, train loss: 1125.971
#
# Epoch: 90/600, train loss: 1125.061
#
# Epoch: 91/600, train loss: 1124.576
#
# Epoch: 92/600, train loss: 1123.866
#
# Epoch: 93/600, train loss: 1123.452
#
# Epoch: 94/600, train loss: 1122.564
#
# Epoch: 95/600, train loss: 1121.937
#
# Epoch: 96/600, train loss: 1121.216
#
# Epoch: 97/600, train loss: 1120.690
#
# Epoch: 98/600, train loss: 1120.028
#
# Epoch: 99/600, train loss: 1119.507
#
# Epoch: 100/600, train loss: 1118.684
#
# Epoch: 101/600, train loss: 1118.381
#
# Epoch: 102/600, train loss: 1117.519
#
# Epoch: 103/600, train loss: 1117.080
#
# Epoch: 104/600, train loss: 1116.412
#
# Epoch: 105/600, train loss: 1116.156
#
# Epoch: 106/600, train loss: 1115.402
#
# Epoch: 107/600, train loss: 1114.834
#
# Epoch: 108/600, train loss: 1114.466
#
# Epoch: 109/600, train loss: 1113.877
#
# Epoch: 110/600, train loss: 1113.729
#
# Epoch: 111/600, train loss: 1113.029
#
# Epoch: 112/600, train loss: 1112.573
#
# Epoch: 113/600, train loss: 1112.035
#
# Epoch: 114/600, train loss: 1111.619
#
# Epoch: 115/600, train loss: 1110.975
#
# Epoch: 116/600, train loss: 1110.418
#
# Epoch: 117/600, train loss: 1110.134
#
# Epoch: 118/600, train loss: 1109.576
#
# Epoch: 119/600, train loss: 1108.877
#
# Epoch: 120/600, train loss: 1108.591
#
# Epoch: 121/600, train loss: 1108.300
#
# Epoch: 122/600, train loss: 1107.722
#
# Epoch: 123/600, train loss: 1107.276
#
# Epoch: 124/600, train loss: 1106.819
#
# Epoch: 125/600, train loss: 1106.393
#
# Epoch: 126/600, train loss: 1106.266
#
# Epoch: 127/600, train loss: 1105.414
#
# Epoch: 128/600, train loss: 1104.751
#
# Epoch: 129/600, train loss: 1104.643
#
# Epoch: 130/600, train loss: 1104.188
#
# Epoch: 131/600, train loss: 1104.045
#
# Epoch: 132/600, train loss: 1103.460
#
# Epoch: 133/600, train loss: 1102.715
#
# Epoch: 134/600, train loss: 1102.635
#
# Epoch: 135/600, train loss: 1102.114
#
# Epoch: 136/600, train loss: 1101.469
#
# Epoch: 137/600, train loss: 1101.344
#
# Epoch: 138/600, train loss: 1100.944
#
# Epoch: 139/600, train loss: 1100.646
#
# Epoch: 140/600, train loss: 1099.967
#
# Epoch: 141/600, train loss: 1100.020
#
# Epoch: 142/600, train loss: 1099.611
#
# Epoch: 143/600, train loss: 1099.073
#
# Epoch: 144/600, train loss: 1098.489
#
# Epoch: 145/600, train loss: 1098.407
#
# Epoch: 146/600, train loss: 1098.139
#
# Epoch: 147/600, train loss: 1097.495
#
# Epoch: 148/600, train loss: 1097.386
#
# Epoch: 149/600, train loss: 1097.316
#
# Epoch: 150/600, train loss: 1096.540
#
# Epoch: 151/600, train loss: 1096.042
#
# Epoch: 152/600, train loss: 1095.866
#
# Epoch: 153/600, train loss: 1095.668
#
# Epoch: 154/600, train loss: 1095.405
#
# Epoch: 155/600, train loss: 1094.889
#
# Epoch: 156/600, train loss: 1094.810
#
# Epoch: 157/600, train loss: 1094.579
#
# Epoch: 158/600, train loss: 1094.458
#
# Epoch: 159/600, train loss: 1094.028
#
# Epoch: 160/600, train loss: 1093.613
#
# Epoch: 161/600, train loss: 1093.399
#
# Epoch: 162/600, train loss: 1092.933
#
# Epoch: 163/600, train loss: 1092.741
#
# Epoch: 164/600, train loss: 1092.496
#
# Epoch: 165/600, train loss: 1092.170
#
# Epoch: 166/600, train loss: 1091.990
#
# Epoch: 167/600, train loss: 1091.482
#
# Epoch: 168/600, train loss: 1091.234
#
# Epoch: 169/600, train loss: 1091.165
#
# Epoch: 170/600, train loss: 1090.835
#
# Epoch: 171/600, train loss: 1090.298
#
# Epoch: 172/600, train loss: 1089.905
#
# Epoch: 173/600, train loss: 1089.734
#
# Epoch: 174/600, train loss: 1089.743
#
# Epoch: 175/600, train loss: 1089.332
#
# Epoch: 176/600, train loss: 1089.143
#
# Epoch: 177/600, train loss: 1088.660
#
# Epoch: 178/600, train loss: 1088.585
#
# Epoch: 179/600, train loss: 1088.382
#
# Epoch: 180/600, train loss: 1088.334
#
# Epoch: 181/600, train loss: 1087.639
#
# Epoch: 182/600, train loss: 1087.489
#
# Epoch: 183/600, train loss: 1087.255
#
# Epoch: 184/600, train loss: 1087.008
#
# Epoch: 185/600, train loss: 1086.895
#
# Epoch: 186/600, train loss: 1086.550
#
# Epoch: 187/600, train loss: 1086.546
#
# Epoch: 188/600, train loss: 1086.092
#
# Epoch: 189/600, train loss: 1085.962
#
# Epoch: 190/600, train loss: 1085.832
#
# Epoch: 191/600, train loss: 1085.490
#
# Epoch: 192/600, train loss: 1085.502
#
# Epoch: 193/600, train loss: 1085.361
#
# Epoch: 194/600, train loss: 1084.956
#
# Epoch: 195/600, train loss: 1085.012
#
# Epoch: 196/600, train loss: 1084.694
#
# Epoch: 197/600, train loss: 1083.955
#
# Epoch: 198/600, train loss: 1083.947
#
# Epoch: 199/600, train loss: 1083.950
#
# Epoch: 200/600, train loss: 1083.458
#
# Epoch: 201/600, train loss: 1083.458
#
# Epoch: 202/600, train loss: 1083.380
#
# Epoch: 203/600, train loss: 1083.077
#
# Epoch: 204/600, train loss: 1083.097
#
# Epoch: 205/600, train loss: 1082.773
#
# Epoch: 206/600, train loss: 1082.509
#
# Epoch: 207/600, train loss: 1082.480
#
# Epoch: 208/600, train loss: 1082.453
#
# Epoch: 209/600, train loss: 1082.233
#
# Epoch: 210/600, train loss: 1081.929
#
# Epoch: 211/600, train loss: 1081.845
#
# Epoch: 212/600, train loss: 1081.544
#
# Epoch: 213/600, train loss: 1081.412
#
# Epoch: 214/600, train loss: 1081.221
#
# Epoch: 215/600, train loss: 1081.191
#
# Epoch: 216/600, train loss: 1080.774
#
# Epoch: 217/600, train loss: 1080.812
#
# Epoch: 218/600, train loss: 1080.526
#
# Epoch: 219/600, train loss: 1080.435
#
# Epoch: 220/600, train loss: 1080.291
#
# Epoch: 221/600, train loss: 1080.034
#
# Epoch: 222/600, train loss: 1080.088
#
# Epoch: 223/600, train loss: 1079.808
#
# Epoch: 224/600, train loss: 1079.447
#
# Epoch: 225/600, train loss: 1079.474
#
# Epoch: 226/600, train loss: 1079.337
#
# Epoch: 227/600, train loss: 1079.139
#
# Epoch: 228/600, train loss: 1079.010
#
# Epoch: 229/600, train loss: 1078.779
#
# Epoch: 230/600, train loss: 1078.467
#
# Epoch: 231/600, train loss: 1078.562
#
# Epoch: 232/600, train loss: 1078.481
#
# Epoch: 233/600, train loss: 1078.520
#
# Epoch: 234/600, train loss: 1077.812
#
# Epoch: 235/600, train loss: 1077.994
#
# Epoch: 236/600, train loss: 1077.800
#
# Epoch: 237/600, train loss: 1077.869
#
# Epoch: 238/600, train loss: 1077.516
#
# Epoch: 239/600, train loss: 1077.098
#
# Epoch: 240/600, train loss: 1077.364
#
# Epoch: 241/600, train loss: 1077.083
#
# Epoch: 242/600, train loss: 1077.329
#
# Epoch: 243/600, train loss: 1076.838
#
# Epoch: 244/600, train loss: 1076.857
#
# Epoch: 245/600, train loss: 1076.802
#
# Epoch: 246/600, train loss: 1076.389
#
# Epoch: 247/600, train loss: 1076.458
#
# Epoch: 248/600, train loss: 1076.456
#
# Epoch: 249/600, train loss: 1076.187
#
# Epoch: 250/600, train loss: 1075.841
#
# Epoch: 251/600, train loss: 1075.619
#
# Epoch: 252/600, train loss: 1075.707
#
# Epoch: 253/600, train loss: 1075.621
#
# Epoch: 254/600, train loss: 1075.162
#
# Epoch: 255/600, train loss: 1075.520
#
# Epoch: 256/600, train loss: 1075.340
#
# Epoch: 257/600, train loss: 1074.982
#
# Epoch: 258/600, train loss: 1075.039
#
# Epoch: 259/600, train loss: 1074.901
#
# Epoch: 260/600, train loss: 1074.768
#
# Epoch: 261/600, train loss: 1074.473
#
# Epoch: 262/600, train loss: 1074.570
#
# Epoch: 263/600, train loss: 1074.251
#
# Epoch: 264/600, train loss: 1074.412
#
# Epoch: 265/600, train loss: 1074.262
#
# Epoch: 266/600, train loss: 1073.892
#
# Epoch: 267/600, train loss: 1073.891
#
# Epoch: 268/600, train loss: 1073.772
#
# Epoch: 269/600, train loss: 1073.614
#
# Epoch: 270/600, train loss: 1073.619
#
# Epoch: 271/600, train loss: 1073.842
#
# Epoch: 272/600, train loss: 1073.334
#
# Epoch: 273/600, train loss: 1073.317
#
# Epoch: 274/600, train loss: 1073.009
#
# Epoch: 275/600, train loss: 1072.974
#
# Epoch: 276/600, train loss: 1073.010
#
# Epoch: 277/600, train loss: 1072.595
#
# Epoch: 278/600, train loss: 1072.866
#
# Epoch: 279/600, train loss: 1072.517
#
# Epoch: 280/600, train loss: 1072.436
#
# Epoch: 281/600, train loss: 1072.596
#
# Epoch: 282/600, train loss: 1072.239
#
# Epoch: 283/600, train loss: 1072.272
#
# Epoch: 284/600, train loss: 1071.893
#
# Epoch: 285/600, train loss: 1072.152
#
# Epoch: 286/600, train loss: 1071.894
#
# Epoch: 287/600, train loss: 1071.955
#
# Epoch: 288/600, train loss: 1071.595
#
# Epoch: 289/600, train loss: 1071.402
#
# Epoch: 290/600, train loss: 1071.532
#
# Epoch: 291/600, train loss: 1071.460
#
# Epoch: 292/600, train loss: 1071.199
#
# Epoch: 293/600, train loss: 1071.099
#
# Epoch: 294/600, train loss: 1071.018
#
# Epoch: 295/600, train loss: 1070.811
#
# Epoch: 296/600, train loss: 1071.231
#
# Epoch: 297/600, train loss: 1070.684
#
# Epoch: 298/600, train loss: 1070.820
#
# Epoch: 299/600, train loss: 1070.378
#
# Epoch: 300/600, train loss: 1070.524
#
# Epoch: 301/600, train loss: 1070.305
#
# Epoch: 302/600, train loss: 1070.389
#
# Epoch: 303/600, train loss: 1070.280
#
# Epoch: 304/600, train loss: 1070.339
#
# Epoch: 305/600, train loss: 1069.990
#
# Epoch: 306/600, train loss: 1069.830
#
# Epoch: 307/600, train loss: 1069.845
#
# Epoch: 308/600, train loss: 1069.626
#
# Epoch: 309/600, train loss: 1069.563
#
# Epoch: 310/600, train loss: 1069.686
#
# Epoch: 311/600, train loss: 1069.072
#
# Epoch: 312/600, train loss: 1069.462
#
# Epoch: 313/600, train loss: 1069.169
#
# Epoch: 314/600, train loss: 1069.327
#
# Epoch: 315/600, train loss: 1068.979
#
# Epoch: 316/600, train loss: 1069.081
#
# Epoch: 317/600, train loss: 1069.144
#
# Epoch: 318/600, train loss: 1068.937
#
# Epoch: 319/600, train loss: 1068.754
#
# Epoch: 320/600, train loss: 1068.601
#
# Epoch: 321/600, train loss: 1068.577
#
# Epoch: 322/600, train loss: 1068.371
#
# Epoch: 323/600, train loss: 1068.575
#
# Epoch: 324/600, train loss: 1068.579
#
# Epoch: 325/600, train loss: 1068.116
#
# Epoch: 326/600, train loss: 1068.227
#
# Epoch: 327/600, train loss: 1068.323
#
# Epoch: 328/600, train loss: 1067.761
#
# Epoch: 329/600, train loss: 1068.044
#
# Epoch: 330/600, train loss: 1068.317
#
# Epoch: 331/600, train loss: 1067.593
#
# Epoch: 332/600, train loss: 1067.940
#
# Epoch: 333/600, train loss: 1067.754
#
# Epoch: 334/600, train loss: 1067.773
#
# Epoch: 335/600, train loss: 1067.489
#
# Epoch: 336/600, train loss: 1067.565
#
# Epoch: 337/600, train loss: 1067.475
#
# Epoch: 338/600, train loss: 1067.148
#
# Epoch: 339/600, train loss: 1067.166
#
# Epoch: 340/600, train loss: 1067.131
#
# Epoch: 341/600, train loss: 1067.139
#
# Epoch: 342/600, train loss: 1066.825
#
# Epoch: 343/600, train loss: 1066.837
#
# Epoch: 344/600, train loss: 1066.980
#
# Epoch: 345/600, train loss: 1066.807
#
# Epoch: 346/600, train loss: 1066.867
#
# Epoch: 347/600, train loss: 1066.828
#
# Epoch: 348/600, train loss: 1066.668
#
# Epoch: 349/600, train loss: 1066.289
#
# Epoch: 350/600, train loss: 1066.265
#
# Epoch: 351/600, train loss: 1066.250
#
# Epoch: 352/600, train loss: 1066.149
#
# Epoch: 353/600, train loss: 1066.156
#
# Epoch: 354/600, train loss: 1066.214
#
# Epoch: 355/600, train loss: 1066.089
#
# Epoch: 356/600, train loss: 1066.212
#
# Epoch: 357/600, train loss: 1065.875
#
# Epoch: 358/600, train loss: 1065.676
#
# Epoch: 359/600, train loss: 1066.074
#
# Epoch: 360/600, train loss: 1065.700
#
# Epoch: 361/600, train loss: 1065.594
#
# Epoch: 362/600, train loss: 1065.533
#
# Epoch: 363/600, train loss: 1065.374
#
# Epoch: 364/600, train loss: 1065.665
#
# Epoch: 365/600, train loss: 1065.435
#
# Epoch: 366/600, train loss: 1065.055
#
# Epoch: 367/600, train loss: 1065.357
#
# Epoch: 368/600, train loss: 1065.117
#
# Epoch: 369/600, train loss: 1064.857
#
# Epoch: 370/600, train loss: 1064.718
#
# Epoch: 371/600, train loss: 1064.967
#
# Epoch: 372/600, train loss: 1065.024
#
# Epoch: 373/600, train loss: 1064.966
#
# Epoch: 374/600, train loss: 1065.051
#
# Epoch: 375/600, train loss: 1064.860
#
# Epoch: 376/600, train loss: 1064.628
#
# Epoch: 377/600, train loss: 1064.775
#
# Epoch: 378/600, train loss: 1064.929
#
# Epoch: 379/600, train loss: 1064.320
#
# Epoch: 380/600, train loss: 1064.274
#
# Epoch: 381/600, train loss: 1064.369
#
# Epoch: 382/600, train loss: 1064.470
#
# Epoch: 383/600, train loss: 1064.183
#
# Epoch: 384/600, train loss: 1064.271
#
# Epoch: 385/600, train loss: 1064.193
#
# Epoch: 386/600, train loss: 1064.073
#
# Epoch: 387/600, train loss: 1064.186
#
# Epoch: 388/600, train loss: 1063.778
#
# Epoch: 389/600, train loss: 1063.988
#
# Epoch: 390/600, train loss: 1064.120
#
# Epoch: 391/600, train loss: 1063.707
#
# Epoch: 392/600, train loss: 1063.846
#
# Epoch: 393/600, train loss: 1063.646
#
# Epoch: 394/600, train loss: 1063.882
#
# Epoch: 395/600, train loss: 1063.648
#
# Epoch: 396/600, train loss: 1063.497
#
# Epoch: 397/600, train loss: 1063.240
#
# Epoch: 398/600, train loss: 1063.301
#
# Epoch: 399/600, train loss: 1063.199
#
# Epoch: 400/600, train loss: 1063.442
#
# Epoch: 401/600, train loss: 1063.172
#
# Epoch: 402/600, train loss: 1063.231
#
# Epoch: 403/600, train loss: 1063.213
#
# Epoch: 404/600, train loss: 1063.126
#
# Epoch: 405/600, train loss: 1063.142
#
# Epoch: 406/600, train loss: 1062.787
#
# Epoch: 407/600, train loss: 1062.868
#
# Epoch: 408/600, train loss: 1062.720
#
# Epoch: 409/600, train loss: 1062.795
#
# Epoch: 410/600, train loss: 1063.051
#
# Epoch: 411/600, train loss: 1062.817
#
# Epoch: 412/600, train loss: 1062.625
#
# Epoch: 413/600, train loss: 1062.868
#
# Epoch: 414/600, train loss: 1062.529
#
# Epoch: 415/600, train loss: 1062.642
#
# Epoch: 416/600, train loss: 1062.183
#
# Epoch: 417/600, train loss: 1062.299
#
# Epoch: 418/600, train loss: 1062.438
#
# Epoch: 419/600, train loss: 1062.415
#
# Epoch: 420/600, train loss: 1062.202
#
# Epoch: 421/600, train loss: 1062.241
#
# Epoch: 422/600, train loss: 1062.070
#
# Epoch: 423/600, train loss: 1061.765
#
# Epoch: 424/600, train loss: 1062.073
#
# Epoch: 425/600, train loss: 1062.040
#
# Epoch: 426/600, train loss: 1061.917
#
# Epoch: 427/600, train loss: 1062.005
#
# Epoch: 428/600, train loss: 1062.151
#
# Epoch: 429/600, train loss: 1061.967
#
# Epoch: 430/600, train loss: 1061.723
#
# Epoch: 431/600, train loss: 1061.643
#
# Epoch: 432/600, train loss: 1061.803
#
# Epoch: 433/600, train loss: 1061.544
#
# Epoch: 434/600, train loss: 1061.366
#
# Epoch: 435/600, train loss: 1061.442
#
# Epoch: 436/600, train loss: 1061.341
#
# Epoch: 437/600, train loss: 1061.337
#
# Epoch: 438/600, train loss: 1061.302
#
# Epoch: 439/600, train loss: 1060.895
#
# Epoch: 440/600, train loss: 1061.637
#
# Epoch: 441/600, train loss: 1061.120
#
# Epoch: 442/600, train loss: 1061.276
#
# Epoch: 443/600, train loss: 1060.955
#
# Epoch: 444/600, train loss: 1061.263
#
# Epoch: 445/600, train loss: 1061.095
#
# Epoch: 446/600, train loss: 1061.067
#
# Epoch: 447/600, train loss: 1060.638
#
# Epoch: 448/600, train loss: 1060.950
#
# Epoch: 449/600, train loss: 1060.794
#
# Epoch: 450/600, train loss: 1060.818
#
# Epoch: 451/600, train loss: 1060.847
#
# Epoch: 452/600, train loss: 1060.777
#
# Epoch: 453/600, train loss: 1060.836
#
# Epoch: 454/600, train loss: 1060.514
#
# Epoch: 455/600, train loss: 1060.428
#
# Epoch: 456/600, train loss: 1060.672
#
# Epoch: 457/600, train loss: 1060.922
#
# Epoch: 458/600, train loss: 1060.235
#
# Epoch: 459/600, train loss: 1060.506
#
# Epoch: 460/600, train loss: 1060.700
#
# Epoch: 461/600, train loss: 1060.441
#
# Epoch: 462/600, train loss: 1060.316
#
# Epoch: 463/600, train loss: 1060.374
#
# Epoch: 464/600, train loss: 1060.152
#
# Epoch: 465/600, train loss: 1059.918
#
# Epoch: 466/600, train loss: 1059.888
#
# Epoch: 467/600, train loss: 1060.062
#
# Epoch: 468/600, train loss: 1059.888
#
# Epoch: 469/600, train loss: 1059.978
#
# Epoch: 470/600, train loss: 1060.042
#
# Epoch: 471/600, train loss: 1059.954
#
# Epoch: 472/600, train loss: 1059.895
#
# Epoch: 473/600, train loss: 1059.871
#
# Epoch: 474/600, train loss: 1059.856
#
# Epoch: 475/600, train loss: 1059.677
#
# Epoch: 476/600, train loss: 1059.922
#
# Epoch: 477/600, train loss: 1059.885
#
# Epoch: 478/600, train loss: 1059.761
#
# Epoch: 479/600, train loss: 1059.765
#
# Epoch: 480/600, train loss: 1059.525
#
# Epoch: 481/600, train loss: 1059.304
#
# Epoch: 482/600, train loss: 1059.726
#
# Epoch: 483/600, train loss: 1059.345
#
# Epoch: 484/600, train loss: 1059.532
#
# Epoch: 485/600, train loss: 1059.420
#
# Epoch: 486/600, train loss: 1059.358
#
# Epoch: 487/600, train loss: 1059.376
#
# Epoch: 488/600, train loss: 1059.431
#
# Epoch: 489/600, train loss: 1059.217
#
# Epoch: 490/600, train loss: 1059.091
#
# Epoch: 491/600, train loss: 1059.181
#
# Epoch: 492/600, train loss: 1059.163
#
# Epoch: 493/600, train loss: 1059.171
#
# Epoch: 494/600, train loss: 1059.240
#
# Epoch: 495/600, train loss: 1059.277
#
# Epoch: 496/600, train loss: 1058.708
#
# Epoch: 497/600, train loss: 1058.904
#
# Epoch: 498/600, train loss: 1059.025
#
# Epoch: 499/600, train loss: 1058.748
#
# Epoch: 500/600, train loss: 1058.665
#
# Epoch: 501/600, train loss: 1058.891
#
# Epoch: 502/600, train loss: 1058.666
#
# Epoch: 503/600, train loss: 1058.521
#
# Epoch: 504/600, train loss: 1058.742
#
# Epoch: 505/600, train loss: 1058.464
#
# Epoch: 506/600, train loss: 1058.631
#
# Epoch: 507/600, train loss: 1058.733
#
# Epoch: 508/600, train loss: 1058.515
#
# Epoch: 509/600, train loss: 1058.358
#
# Epoch: 510/600, train loss: 1058.295
#
# Epoch: 511/600, train loss: 1058.611
#
# Epoch: 512/600, train loss: 1058.404
#
# Epoch: 513/600, train loss: 1058.440
#
# Epoch: 514/600, train loss: 1058.470
#
# Epoch: 515/600, train loss: 1058.687
#
# Epoch: 516/600, train loss: 1058.325
#
# Epoch: 517/600, train loss: 1058.364
#
# Epoch: 518/600, train loss: 1058.343
#
# Epoch: 519/600, train loss: 1058.096
#
# Epoch: 520/600, train loss: 1058.175
#
# Epoch: 521/600, train loss: 1058.324
#
# Epoch: 522/600, train loss: 1057.732
#
# Epoch: 523/600, train loss: 1058.045
#
# Epoch: 524/600, train loss: 1058.006
#
# Epoch: 525/600, train loss: 1058.004
#
# Epoch: 526/600, train loss: 1057.981
#
# Epoch: 527/600, train loss: 1058.105
#
# Epoch: 528/600, train loss: 1057.853
#
# Epoch: 529/600, train loss: 1057.960
#
# Epoch: 530/600, train loss: 1057.801
#
# Epoch: 531/600, train loss: 1057.502
#
# Epoch: 532/600, train loss: 1057.827
#
# Epoch: 533/600, train loss: 1057.824
#
# Epoch: 534/600, train loss: 1057.441
#
# Epoch: 535/600, train loss: 1057.836
#
# Epoch: 536/600, train loss: 1057.745
#
# Epoch: 537/600, train loss: 1057.671
#
# Epoch: 538/600, train loss: 1057.367
#
# Epoch: 539/600, train loss: 1057.379
#
# Epoch: 540/600, train loss: 1057.626
#
# Epoch: 541/600, train loss: 1057.267
#
# Epoch: 542/600, train loss: 1057.542
#
# Epoch: 543/600, train loss: 1057.428
#
# Epoch: 544/600, train loss: 1057.471
#
# Epoch: 545/600, train loss: 1057.262
#
# Epoch: 546/600, train loss: 1057.195
#
# Epoch: 547/600, train loss: 1057.419
#
# Epoch: 548/600, train loss: 1057.077
#
# Epoch: 549/600, train loss: 1057.178
#
# Epoch: 550/600, train loss: 1057.134
#
# Epoch: 551/600, train loss: 1057.172
#
# Epoch: 552/600, train loss: 1056.938
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 553/600, train loss: 1011.752
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 554/600, train loss: 995.782
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 555/600, train loss: 986.083
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 556/600, train loss: 979.140
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 557/600, train loss: 973.375
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 558/600, train loss: 968.023
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 559/600, train loss: 962.969
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 560/600, train loss: 958.113
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 561/600, train loss: 953.308
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 562/600, train loss: 948.927
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 563/600, train loss: 944.474
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 564/600, train loss: 940.513
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 565/600, train loss: 936.326
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 566/600, train loss: 931.873
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 567/600, train loss: 928.663
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 568/600, train loss: 924.719
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 569/600, train loss: 921.497
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 570/600, train loss: 918.167
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 571/600, train loss: 914.825
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 572/600, train loss: 912.215
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 573/600, train loss: 910.176
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 574/600, train loss: 908.195
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 575/600, train loss: 906.272
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 576/600, train loss: 904.935
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 577/600, train loss: 903.732
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 578/600, train loss: 902.188
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 579/600, train loss: 901.196
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 580/600, train loss: 900.646
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 581/600, train loss: 899.148
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 582/600, train loss: 898.526
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 583/600, train loss: 897.734
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 584/600, train loss: 897.259
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 585/600, train loss: 897.372
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 586/600, train loss: 895.669
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 587/600, train loss: 895.552
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 588/600, train loss: 895.163
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 589/600, train loss: 894.627
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 590/600, train loss: 894.272
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 591/600, train loss: 893.949
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 592/600, train loss: 893.637
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 593/600, train loss: 893.063
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 594/600, train loss: 892.720
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 595/600, train loss: 892.336
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 596/600, train loss: 892.133
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 597/600, train loss: 891.840
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 598/600, train loss: 891.830
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 599/600, train loss: 891.575
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 600/600, train loss: 891.039
#
# Inferring ...
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']

# %%
infer_latent(only_joint=False, impute=False, save_input=True)###
# Out:
# Inferring ...
# /root/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Subset: 0, modalities ['rna']: test size: 34558
# Processing subset 0: ['rna']
# Removing directory "result/Zilionis/e0/default/represent/subset_0/z/joint"
# Removing directory "result/Zilionis/e0/default/represent/subset_0/z/rna"
# Removing directory "result/Zilionis/e0/default/represent/subset_0/x_r_pre/rna"
# Removing directory "result/Zilionis/e0/default/represent/subset_0/x/rna"
# 100%|██████████| 68/68 [02:01<00:00,  1.79s/it]
# ari: 0.9127974542221803
# nmi: 0.9018404212449289
# sc: 0.6066246628761292
